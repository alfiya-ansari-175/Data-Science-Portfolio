# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input,Dense,Embedding,Flatten,Concatenate,Dropout,BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
import shap
import tensorflow as tf

# %%
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 50)

# %%
df = pd.read_csv('/Users/alfiyaansari/Desktop/IHMStefanini_industrial_safety_and_health_database_with_accidents_description.csv')
df.head()
# Out:
#    Unnamed: 0                 Data   Countries     Local Industry Sector  \
# 0           0  2016-01-01 00:00:00  Country_01  Local_01          Mining
# 1           1  2016-01-02 00:00:00  Country_02  Local_02          Mining
# 2           2  2016-01-06 00:00:00  Country_01  Local_03          Mining
# 3           3  2016-01-08 00:00:00  Country_01  Local_04          Mining
# 4           4  2016-01-10 00:00:00  Country_01  Local_04          Mining
#
#   Accident Level Potential Accident Level Genre Employee or Third Party  \
# 0              I                       IV  Male             Third Party
# 1              I                       IV  Male                Employee
# 2              I                      III  Male    Third Party (Remote)
# 3              I                        I  Male             Third Party
# 4             IV                       IV  Male             Third Party
#
#          Critical Risk                                        Description
# 0              Pressed  While removing the drill rod of the Jumbo 08 f...
# 1  Pressurized Systems  During the activation of a sodium sulphide pum...
# 2         Manual Tools  In the sub-station MILPO located at level +170...
# 3               Others  Being 9:45 am. approximately in the Nv. 1880 C...
# 4               Others  Approximately at 11:45 a.m. in circumstances t...

# %%
categorical_features = [
    "Countries",
    "Local",
    "Industry Sector",
    "Genre",
    "Employee or Third Party",
    "Critical Risk",
    "Potential Accident Level"
]

# %%
for col in categorical_features:
    df[col] = (
        df[col]
        .astype(str)
        .str.strip()
        .str.lower()
    )

# %%
severity_map = {
    "i": 1,
    "ii": 2,
    "iii": 3,
    "iv": 4,
    "v": 5
}

df["risk_score"] = (
    df["Accident Level"]
    .astype(str)
    .str.strip()
    .str.lower()
    .map(severity_map)
)

df = df.dropna(subset=["risk_score"])

# %%
df["severe_accident"] = (df["risk_score"] >= 4).astype(int)

# %%
encoders = {}

for col in categorical_features:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = le

# %%
X = df[categorical_features]

y_risk = df["risk_score"]
y_severe = df["severe_accident"]

X_train, X_test, y_risk_train, y_risk_test, y_severe_train, y_severe_test = train_test_split(
    X, y_risk, y_severe,
    test_size=0.2,
    random_state=42
)

# %%
def build_model():
    inputs = []
    embeddings = []

    for col in categorical_features:
        inp = Input(shape=(1,), name=f"{col}_input")
        vocab_size = df[col].nunique() + 1

        emb = Embedding(vocab_size, 16)(inp)
        emb = Flatten()(emb)

        inputs.append(inp)
        embeddings.append(emb)

    x = Concatenate()(embeddings)

    x = Dense(128, activation="relu", kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    x = Dense(64, activation="relu")(x)

    risk_output = Dense(1, activation="linear", name="risk_score")(x)
    severe_output = Dense(1, activation="sigmoid", name="severe_probability")(x)

    model = Model(inputs=inputs, outputs=[risk_output, severe_output])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(0.001),
        loss={
            "risk_score": tf.keras.losses.Huber(),
            "severe_probability": "binary_crossentropy"
        },
        metrics={
            "risk_score": "mae",
            "severe_probability": "accuracy"
        }
    )

    return model

# %%
model = build_model()

model.fit(
    [X_train[col] for col in categorical_features],
    {
        "risk_score": y_risk_train,
        "severe_probability": y_severe_train
    },
    validation_split=0.2,
    epochs=50,
    batch_size=32,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            patience=5,
            restore_best_weights=True
        )
    ],
    verbose=1
)
# Out:
# Epoch 1/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7045 - risk_score_loss: 0.8344 - risk_score_mae: 1.2536 - severe_probability_accuracy: 0.3510 - severe_probability_loss: 0.7517 - val_loss: 1.6912 - val_risk_score_loss: 1.0417 - val_risk_score_mae: 1.4006 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.6692
# Epoch 2/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1991 - risk_score_loss: 0.4887 - risk_score_mae: 0.8256 - severe_probability_accuracy: 0.7290 - severe_probability_loss: 0.5937 - val_loss: 1.5743 - val_risk_score_loss: 0.9564 - val_risk_score_mae: 1.3063 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.6338
# Epoch 3/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9206 - risk_score_loss: 0.3667 - risk_score_mae: 0.6971 - severe_probability_accuracy: 0.9230 - severe_probability_loss: 0.4342 - val_loss: 1.5147 - val_risk_score_loss: 0.9414 - val_risk_score_mae: 1.2887 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.5859
# Epoch 4/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7896 - risk_score_loss: 0.3173 - risk_score_mae: 0.6363 - severe_probability_accuracy: 0.8980 - severe_probability_loss: 0.3565 - val_loss: 1.4764 - val_risk_score_loss: 0.9377 - val_risk_score_mae: 1.2856 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.5478
# Epoch 5/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6735 - risk_score_loss: 0.2766 - risk_score_mae: 0.5788 - severe_probability_accuracy: 0.9338 - severe_probability_loss: 0.2800 - val_loss: 1.4414 - val_risk_score_loss: 0.9317 - val_risk_score_mae: 1.2782 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.5180
# Epoch 6/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6414 - risk_score_loss: 0.2750 - risk_score_mae: 0.5942 - severe_probability_accuracy: 0.9173 - severe_probability_loss: 0.2522 - val_loss: 1.4106 - val_risk_score_loss: 0.9246 - val_risk_score_mae: 1.2706 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.4927
# Epoch 7/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5804 - risk_score_loss: 0.2340 - risk_score_mae: 0.5285 - severe_probability_accuracy: 0.9087 - severe_probability_loss: 0.2321 - val_loss: 1.3780 - val_risk_score_loss: 0.9116 - val_risk_score_mae: 1.2560 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.4720
# Epoch 8/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5241 - risk_score_loss: 0.2379 - risk_score_mae: 0.5395 - severe_probability_accuracy: 0.9501 - severe_probability_loss: 0.1787 - val_loss: 1.3737 - val_risk_score_loss: 0.9232 - val_risk_score_mae: 1.2710 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.4554
# Epoch 9/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5230 - risk_score_loss: 0.2102 - risk_score_mae: 0.4926 - severe_probability_accuracy: 0.9236 - severe_probability_loss: 0.2008 - val_loss: 1.3473 - val_risk_score_loss: 0.9117 - val_risk_score_mae: 1.2594 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.4379
# Epoch 10/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5341 - risk_score_loss: 0.2448 - risk_score_mae: 0.5351 - severe_probability_accuracy: 0.9376 - severe_probability_loss: 0.1777 - val_loss: 1.3143 - val_risk_score_loss: 0.8965 - val_risk_score_mae: 1.2380 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.4204
# Epoch 11/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4843 - risk_score_loss: 0.2181 - risk_score_mae: 0.5034 - severe_probability_accuracy: 0.9507 - severe_probability_loss: 0.1555 - val_loss: 1.3043 - val_risk_score_loss: 0.8985 - val_risk_score_mae: 1.2431 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.4068
# Epoch 12/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4654 - risk_score_loss: 0.2011 - risk_score_mae: 0.4640 - severe_probability_accuracy: 0.9541 - severe_probability_loss: 0.1532 - val_loss: 1.2717 - val_risk_score_loss: 0.8797 - val_risk_score_mae: 1.2168 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.3946
# Epoch 13/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5157 - risk_score_loss: 0.2105 - risk_score_mae: 0.4687 - severe_probability_accuracy: 0.9292 - severe_probability_loss: 0.1951 - val_loss: 1.2357 - val_risk_score_loss: 0.8537 - val_risk_score_mae: 1.1851 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.3833
# Epoch 14/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4728 - risk_score_loss: 0.2069 - risk_score_mae: 0.4847 - severe_probability_accuracy: 0.9366 - severe_probability_loss: 0.1571 - val_loss: 1.2091 - val_risk_score_loss: 0.8384 - val_risk_score_mae: 1.1656 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.3697
# Epoch 15/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4795 - risk_score_loss: 0.2003 - risk_score_mae: 0.4777 - severe_probability_accuracy: 0.9266 - severe_probability_loss: 0.1722 - val_loss: 1.1896 - val_risk_score_loss: 0.8307 - val_risk_score_mae: 1.1525 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.3586
# Epoch 16/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4401 - risk_score_loss: 0.1818 - risk_score_mae: 0.4452 - severe_probability_accuracy: 0.9333 - severe_probability_loss: 0.1514 - val_loss: 1.1483 - val_risk_score_loss: 0.7998 - val_risk_score_mae: 1.1127 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.3464
# Epoch 17/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4221 - risk_score_loss: 0.1672 - risk_score_mae: 0.4357 - severe_probability_accuracy: 0.9305 - severe_probability_loss: 0.1535 - val_loss: 1.1295 - val_risk_score_loss: 0.7895 - val_risk_score_mae: 1.0968 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.3384
# Epoch 18/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4454 - risk_score_loss: 0.1830 - risk_score_mae: 0.4520 - severe_probability_accuracy: 0.9500 - severe_probability_loss: 0.1580 - val_loss: 1.1048 - val_risk_score_loss: 0.7708 - val_risk_score_mae: 1.0730 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.3295
# Epoch 19/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3445 - risk_score_loss: 0.1292 - risk_score_mae: 0.3667 - severe_probability_accuracy: 0.9629 - severe_probability_loss: 0.1137 - val_loss: 1.0999 - val_risk_score_loss: 0.7727 - val_risk_score_mae: 1.0778 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.3196
# Epoch 20/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3661 - risk_score_loss: 0.1474 - risk_score_mae: 0.4011 - severe_probability_accuracy: 0.9566 - severe_probability_loss: 0.1197 - val_loss: 1.0652 - val_risk_score_loss: 0.7469 - val_risk_score_mae: 1.0393 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.3145
# Epoch 21/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4149 - risk_score_loss: 0.1874 - risk_score_mae: 0.4422 - severe_probability_accuracy: 0.9666 - severe_probability_loss: 0.1303 - val_loss: 1.0629 - val_risk_score_loss: 0.7489 - val_risk_score_mae: 1.0456 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.3083
# Epoch 22/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3721 - risk_score_loss: 0.1599 - risk_score_mae: 0.4169 - severe_probability_accuracy: 0.9620 - severe_probability_loss: 0.1119 - val_loss: 1.0412 - val_risk_score_loss: 0.7398 - val_risk_score_mae: 1.0260 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.3020
# Epoch 23/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3737 - risk_score_loss: 0.1685 - risk_score_mae: 0.4180 - severe_probability_accuracy: 0.9707 - severe_probability_loss: 0.1067 - val_loss: 1.0291 - val_risk_score_loss: 0.7377 - val_risk_score_mae: 1.0216 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2922
# Epoch 24/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3820 - risk_score_loss: 0.1611 - risk_score_mae: 0.4010 - severe_probability_accuracy: 0.9519 - severe_probability_loss: 0.1248 - val_loss: 0.9908 - val_risk_score_loss: 0.7066 - val_risk_score_mae: 0.9737 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2813
# Epoch 25/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3263 - risk_score_loss: 0.1179 - risk_score_mae: 0.3408 - severe_probability_accuracy: 0.9706 - severe_probability_loss: 0.1155 - val_loss: 0.9730 - val_risk_score_loss: 0.6948 - val_risk_score_mae: 0.9550 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2738
# Epoch 26/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3698 - risk_score_loss: 0.1433 - risk_score_mae: 0.4004 - severe_probability_accuracy: 0.9579 - severe_probability_loss: 0.1274 - val_loss: 0.9716 - val_risk_score_loss: 0.6964 - val_risk_score_mae: 0.9601 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2731
# Epoch 27/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3796 - risk_score_loss: 0.1626 - risk_score_mae: 0.4017 - severe_probability_accuracy: 0.9543 - severe_probability_loss: 0.1184 - val_loss: 0.9691 - val_risk_score_loss: 0.7029 - val_risk_score_mae: 0.9597 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2682
# Epoch 28/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3760 - risk_score_loss: 0.1606 - risk_score_mae: 0.4172 - severe_probability_accuracy: 0.9547 - severe_probability_loss: 0.1175 - val_loss: 0.9438 - val_risk_score_loss: 0.6817 - val_risk_score_mae: 0.9283 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2638
# Epoch 29/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3381 - risk_score_loss: 0.1361 - risk_score_mae: 0.3799 - severe_probability_accuracy: 0.9707 - severe_probability_loss: 0.1039 - val_loss: 0.9313 - val_risk_score_loss: 0.6729 - val_risk_score_mae: 0.9168 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2600
# Epoch 30/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3323 - risk_score_loss: 0.1472 - risk_score_mae: 0.3894 - severe_probability_accuracy: 0.9727 - severe_probability_loss: 0.0923 - val_loss: 0.9276 - val_risk_score_loss: 0.6728 - val_risk_score_mae: 0.9189 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2551
# Epoch 31/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3519 - risk_score_loss: 0.1381 - risk_score_mae: 0.3855 - severe_probability_accuracy: 0.9536 - severe_probability_loss: 0.1188 - val_loss: 0.9265 - val_risk_score_loss: 0.6758 - val_risk_score_mae: 0.9259 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2527
# Epoch 32/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3521 - risk_score_loss: 0.1507 - risk_score_mae: 0.4007 - severe_probability_accuracy: 0.9725 - severe_probability_loss: 0.1063 - val_loss: 0.9281 - val_risk_score_loss: 0.6841 - val_risk_score_mae: 0.9299 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2513
# Epoch 33/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3783 - risk_score_loss: 0.1625 - risk_score_mae: 0.4068 - severe_probability_accuracy: 0.9600 - severe_probability_loss: 0.1207 - val_loss: 0.9144 - val_risk_score_loss: 0.6754 - val_risk_score_mae: 0.9107 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2463
# Epoch 34/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3241 - risk_score_loss: 0.1315 - risk_score_mae: 0.3643 - severe_probability_accuracy: 0.9644 - severe_probability_loss: 0.0985 - val_loss: 0.8915 - val_risk_score_loss: 0.6561 - val_risk_score_mae: 0.8796 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2402
# Epoch 35/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3286 - risk_score_loss: 0.1490 - risk_score_mae: 0.3818 - severe_probability_accuracy: 0.9743 - severe_probability_loss: 0.0877 - val_loss: 0.8889 - val_risk_score_loss: 0.6599 - val_risk_score_mae: 0.8814 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2351
# Epoch 36/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3556 - risk_score_loss: 0.1491 - risk_score_mae: 0.3866 - severe_probability_accuracy: 0.9623 - severe_probability_loss: 0.1148 - val_loss: 0.8789 - val_risk_score_loss: 0.6422 - val_risk_score_mae: 0.8717 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2333
# Epoch 37/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3379 - risk_score_loss: 0.1532 - risk_score_mae: 0.3767 - severe_probability_accuracy: 0.9568 - severe_probability_loss: 0.0928 - val_loss: 0.8671 - val_risk_score_loss: 0.6292 - val_risk_score_mae: 0.8419 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2361
# Epoch 38/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3446 - risk_score_loss: 0.1528 - risk_score_mae: 0.3982 - severe_probability_accuracy: 0.9696 - severe_probability_loss: 0.1003 - val_loss: 0.8625 - val_risk_score_loss: 0.6333 - val_risk_score_mae: 0.8418 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2334
# Epoch 39/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3338 - risk_score_loss: 0.1323 - risk_score_mae: 0.3595 - severe_probability_accuracy: 0.9468 - severe_probability_loss: 0.1153 - val_loss: 0.8406 - val_risk_score_loss: 0.6200 - val_risk_score_mae: 0.8141 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2260
# Epoch 40/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3273 - risk_score_loss: 0.1380 - risk_score_mae: 0.3644 - severe_probability_accuracy: 0.9504 - severe_probability_loss: 0.1001 - val_loss: 0.8350 - val_risk_score_loss: 0.6125 - val_risk_score_mae: 0.8090 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2258
# Epoch 41/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3195 - risk_score_loss: 0.1458 - risk_score_mae: 0.3931 - severe_probability_accuracy: 0.9695 - severe_probability_loss: 0.0848 - val_loss: 0.8290 - val_risk_score_loss: 0.6088 - val_risk_score_mae: 0.8028 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2227
# Epoch 42/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3178 - risk_score_loss: 0.1394 - risk_score_mae: 0.3657 - severe_probability_accuracy: 0.9712 - severe_probability_loss: 0.0921 - val_loss: 0.8026 - val_risk_score_loss: 0.5778 - val_risk_score_mae: 0.7543 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2282
# Epoch 43/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3343 - risk_score_loss: 0.1442 - risk_score_mae: 0.3838 - severe_probability_accuracy: 0.9653 - severe_probability_loss: 0.1041 - val_loss: 0.8071 - val_risk_score_loss: 0.5837 - val_risk_score_mae: 0.7758 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2230
# Epoch 44/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3609 - risk_score_loss: 0.1647 - risk_score_mae: 0.3898 - severe_probability_accuracy: 0.9569 - severe_probability_loss: 0.1085 - val_loss: 0.7832 - val_risk_score_loss: 0.5575 - val_risk_score_mae: 0.7273 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2205
# Epoch 45/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3445 - risk_score_loss: 0.1522 - risk_score_mae: 0.3775 - severe_probability_accuracy: 0.9440 - severe_probability_loss: 0.1046 - val_loss: 0.7988 - val_risk_score_loss: 0.5667 - val_risk_score_mae: 0.7408 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2177
# Epoch 46/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3735 - risk_score_loss: 0.1589 - risk_score_mae: 0.3947 - severe_probability_accuracy: 0.9528 - severe_probability_loss: 0.1296 - val_loss: 0.7828 - val_risk_score_loss: 0.5442 - val_risk_score_mae: 0.7274 - val_severe_probability_accuracy: 0.8971 - val_severe_probability_loss: 0.2249
# Epoch 47/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3332 - risk_score_loss: 0.1458 - risk_score_mae: 0.3648 - severe_probability_accuracy: 0.9644 - severe_probability_loss: 0.1021 - val_loss: 0.7770 - val_risk_score_loss: 0.5499 - val_risk_score_mae: 0.7172 - val_severe_probability_accuracy: 0.8971 - val_severe_probability_loss: 0.2149
# Epoch 48/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2850 - risk_score_loss: 0.1134 - risk_score_mae: 0.3357 - severe_probability_accuracy: 0.9726 - severe_probability_loss: 0.0884 - val_loss: 0.7807 - val_risk_score_loss: 0.5493 - val_risk_score_mae: 0.7285 - val_severe_probability_accuracy: 0.8971 - val_severe_probability_loss: 0.2113
# Epoch 49/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2990 - risk_score_loss: 0.1233 - risk_score_mae: 0.3406 - severe_probability_accuracy: 0.9613 - severe_probability_loss: 0.0916 - val_loss: 0.7574 - val_risk_score_loss: 0.5266 - val_risk_score_mae: 0.6961 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2099
# Epoch 50/50
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3163 - risk_score_loss: 0.1481 - risk_score_mae: 0.3804 - severe_probability_accuracy: 0.9604 - severe_probability_loss: 0.0866 - val_loss: 0.7399 - val_risk_score_loss: 0.5046 - val_risk_score_mae: 0.6698 - val_severe_probability_accuracy: 0.9118 - val_severe_probability_loss: 0.2184

# %%
def encode_input(input_dict):
    encoded = []

    for col in categorical_features:
        value = input_dict[col].strip().lower()

        if value not in encoders[col].classes_:
            raise ValueError(
                f"Unseen label '{value}' for '{col}'. "
                f"Valid examples: {encoders[col].classes_[:5]}"
            )

        encoded.append(
            np.array([encoders[col].transform([value])[0]])
        )

    return encoded

# %%
def predict_all(model, input_dict):
    encoded = encode_input(input_dict)
    risk, severe = model.predict(encoded, verbose=0)

    return {
        "risk_score": round(float(risk[0][0]), 2),
        "severe_probability": round(float(severe[0][0]), 2)
    }

# %%
def what_if_analysis(model, base_input, modified_input):
    base_pred = predict_all(model, base_input)
    mod_pred = predict_all(model, modified_input)

    return {
        "baseline": base_pred,
        "modified": mod_pred,
        "risk_change": round(
            mod_pred["risk_score"] - base_pred["risk_score"], 2
        )
    }

# %%
base_input = {
    "Countries": encoders["Countries"].classes_[0],
    "Local": encoders["Local"].classes_[0],
    "Industry Sector": encoders["Industry Sector"].classes_[0],
    "Genre": encoders["Genre"].classes_[0],
    "Employee or Third Party": encoders["Employee or Third Party"].classes_[0],
    "Critical Risk": encoders["Critical Risk"].classes_[0],
    "Potential Accident Level": encoders["Potential Accident Level"].classes_[0]
}

modified_input = base_input.copy()
modified_input["Potential Accident Level"] = encoders[
    "Potential Accident Level"
].classes_[-1]

result = what_if_analysis(model, base_input, modified_input)
print(result)
# Out:
# {'baseline': {'risk_score': 0.79, 'severe_probability': 0.02}, 'modified': {'risk_score': 1.31, 'severe_probability': 0.46}, 'risk_change': 0.52}

# %%
model.save("multi_output_accident_model")
