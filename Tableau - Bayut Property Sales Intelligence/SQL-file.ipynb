# %%
#!pip install ipython-sql

# %%
#!pip install PyMySQL

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# %load_ext sql

# %%
# %sql mysql+pymysql://root:admin1234@localhost/tableau_work

# %%
df = pd.read_csv('/Users/alfiyaansari/Desktop/bayut_selling_properties.csv')

# %%
df.shape
# Out:
# (41381, 22)

# %%
df.isnull().sum()
# Out:
# price                        0
# price_category               0
# type                         0
# beds                         0
# baths                        0
# address                      0
# furnishing                   0
# completion_status            0
# post_date                    0
# average_rent                 0
# building_name                0
# year_of_completion           0
# total_parking_spaces         0
# total_floors                 0
# total_building_area_sqft     0
# elevators                    0
# area_name                    0
# city                         0
# country                      0
# Latitude                    18
# Longitude                   18
# purpose                      0
# dtype: int64

# %%
df.dropna(axis=0, inplace=True)

# %%
df.shape
# Out:
# (41363, 22)

# %%
df['price'] = df['price'].apply(lambda x : f"{x:,.0f}")

# %%
pd.set_option('display.max_columns', 50)
df.head(3)
# Out:
#        price price_category       type  beds  baths  \
# 0  1,450,000         Medium  Apartment     1      2
# 1  6,600,000           High  Townhouse     5      5
# 2  4,825,000           High  Apartment     2      3
#
#                                           address   furnishing  \
# 0                    The Bay, Business Bay, Dubai    Furnished
# 1                  Brookfield, DAMAC Hills, Dubai  Unfurnished
# 2  Vida Residence Downtown, Downtown Dubai, Dubai  Unfurnished
#
#   completion_status   post_date  average_rent            building_name  \
# 0             Ready  2024-04-15             0                  Unknown
# 1             Ready  2024-04-15             0                  Unknown
# 2             Ready  2024-04-18        288929  VIDA RESIDENCE DOWNTOWN
#
#    year_of_completion  total_parking_spaces  total_floors  \
# 0                   0                     0             0
# 1                   0                     0             0
# ...

# %%
df['purpose'].value_counts()
# Out:
# purpose
# For Sale    41363
# Name: count, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# UAE    41363
# Name: count, dtype: int64

# %%
len(df['area_name'].value_counts())
# Out:
# 260

# %%
df.head()
# Out:
#        price price_category       type  beds  baths  \
# 0  1,450,000         Medium  Apartment     1      2
# 1  6,600,000           High  Townhouse     5      5
# 2  4,825,000           High  Apartment     2      3
# 3    980,000        Average  Apartment     3      3
# 4  2,499,999         Medium  Townhouse     3      4
#
#                                              address   furnishing  \
# 0                       The Bay, Business Bay, Dubai    Furnished
# 1                     Brookfield, DAMAC Hills, Dubai  Unfurnished
# 2     Vida Residence Downtown, Downtown Dubai, Dubai  Unfurnished
# 3  Building 39, Al Reef Downtown, Al Reef, Abu Dhabi  Unfurnished
# 4                            Nima, The Valley, Dubai    Furnished
#
#   completion_status   post_date  average_rent            building_name  \
# 0             Ready  2024-04-15             0                  Unknown
# 1             Ready  2024-04-15             0                  Unknown
# ...

# %%
len(df['address'].value_counts())
# Out:
# 3883

# %%
df['address'].nunique()
# Out:
# 3883

# %%
df['furnishing'].value_counts()
# Out:
# furnishing
# Unfurnished    31950
# Furnished       9413
# Name: count, dtype: int64

# %%
df['completion_status'].value_counts()
# Out:
# completion_status
# Ready       24887
# Off-Plan    16476
# Name: count, dtype: int64

# %%
df['post_date'].value_counts()
# Out:
# post_date
# 2024-04-17    1484
# 2024-04-22    1436
# 2024-04-15    1392
# 2024-04-18    1308
# 2024-04-19    1262
#               ...
# 2022-11-12       1
# 2023-06-27       1
# 2023-06-24       1
# 2022-05-06       1
# 2022-02-25       1
# Name: count, Length: 457, dtype: int64

# %%
df['address'].value_counts()
# Out:
# address
# Al Yasmeen, Ajman                                                                       361
# Al Zahya, Ajman                                                                         299
# Hayyan, Barashi, Sharjah                                                                256
# Al Mamsha, Muwaileh, Sharjah                                                            248
# Faradis Tower, Al Mamzar, Sharjah                                                       231
#                                                                                        ...
# Tower B2, Vida Hotel, The Hills, Dubai                                                    1
# Al Ghozlan 1, Al Ghozlan, The Greens, Dubai                                               1
# EMR-23, Emirates Cluster, International City, Dubai                                       1
# B2, The Hills B, The Hills, Dubai                                                         1
# ...

# %%
df['city'].value_counts()
# Out:
# city
# Dubai             28809
# Abu Dhabi          6086
# Sharjah            4103
# Ajman              1923
# Ras Al Khaimah      419
# Umm Al Quwain        16
# Al Ain                6
# Fujairah              1
# Name: count, dtype: int64

# %%
df['furnishing'].value_counts()
# Out:
# furnishing
# Unfurnished    31950
# Furnished       9413
# Name: count, dtype: int64

# %%
df['completion_status'].value_counts()
# Out:
# completion_status
# Ready       24887
# Off-Plan    16476
# Name: count, dtype: int64

# %%
df['building_name'].value_counts()
# Out:
# building_name
# Unknown                                  23473
# AYKON CITY-TOWER B                         155
# AYKON CITY (2) -TOWER C                    105
# Forte T1                                    97
# SEVEN HOTEL & APARTMENTS THE PALM - B       80
#                                          ...
# LINKS CANAL                                  1
# PLAZA BOUTIQUE - 15                          1
# Kappa Acca 4                                 1
# MODELUX TOWER 1                              1
# Serenia Living - Tower 2                     1
# Name: count, Length: 1700, dtype: int64

# %%
df['area_name'].value_counts()
# Out:
# area_name
# Jumeirah Village Circle (JVC)    2477
# Business Bay                     2423
# Dubai Marina                     2112
# Downtown Dubai                   2064
# Al Reem Island                   1658
#                                  ...
# Umm Al Quwain Marina                1
# Al Darari                           1
# Al Manara                           1
# Al Yahar                            1
# Asharij                             1
# Name: count, Length: 260, dtype: int64

# %%
df['building_name'].value_counts()
# Out:
# building_name
# Unknown                                  23473
# AYKON CITY-TOWER B                         155
# AYKON CITY (2) -TOWER C                    105
# Forte T1                                    97
# SEVEN HOTEL & APARTMENTS THE PALM - B       80
#                                          ...
# LINKS CANAL                                  1
# PLAZA BOUTIQUE - 15                          1
# Kappa Acca 4                                 1
# MODELUX TOWER 1                              1
# Serenia Living - Tower 2                     1
# Name: count, Length: 1700, dtype: int64

# %%
df['beds'].value_counts()
# Out:
# beds
# 1     11358
# 2     10415
# 3      6963
# 0      4626
# 4      4236
# 5      2770
# 6       649
# 7       200
# 11       63
# 8        48
# 10       24
# 9        11
# Name: count, dtype: int64

# %%
df['furnishing'].value_counts()
# Out:
# furnishing
# Unfurnished    31950
# Furnished       9413
# Name: count, dtype: int64

# %%
df.head()
# Out:
#        price price_category       type  beds  baths  \
# 0  1,450,000         Medium  Apartment     1      2
# 1  6,600,000           High  Townhouse     5      5
# 2  4,825,000           High  Apartment     2      3
# 3    980,000        Average  Apartment     3      3
# 4  2,499,999         Medium  Townhouse     3      4
#
#                                              address   furnishing  \
# 0                       The Bay, Business Bay, Dubai    Furnished
# 1                     Brookfield, DAMAC Hills, Dubai  Unfurnished
# 2     Vida Residence Downtown, Downtown Dubai, Dubai  Unfurnished
# 3  Building 39, Al Reef Downtown, Al Reef, Abu Dhabi  Unfurnished
# 4                            Nima, The Valley, Dubai    Furnished
#
#   completion_status   post_date  average_rent            building_name  \
# 0             Ready  2024-04-15             0                  Unknown
# 1             Ready  2024-04-15             0                  Unknown
# ...

# %%
df.drop(['purpose','country','address','year_of_completion','total_parking_spaces','total_floors',
        'total_floors','total_building_area_sqft','elevators','average_rent','building_name'],axis=1,inplace=True)

# %%
df.head()
# Out:
#        price price_category       type  beds  baths   furnishing  \
# 0  1,450,000         Medium  Apartment     1      2    Furnished
# 1  6,600,000           High  Townhouse     5      5  Unfurnished
# 2  4,825,000           High  Apartment     2      3  Unfurnished
# 3    980,000        Average  Apartment     3      3  Unfurnished
# 4  2,499,999         Medium  Townhouse     3      4    Furnished
#
#   completion_status   post_date       area_name       city   Latitude  \
# 0             Ready  2024-04-15    Business Bay      Dubai  25.189427
# 1             Ready  2024-04-15     DAMAC Hills      Dubai  25.028148
# 2             Ready  2024-04-18  Downtown Dubai      Dubai  25.186684
# 3             Ready  2024-01-03         Al Reef  Abu Dhabi  24.466437
# 4          Off-Plan  2024-02-28      The Valley      Dubai  25.019221
#
#    Longitude
# 0  55.264819
# 1  55.264246
# 2  55.274705
# 3  54.656891
# 4  55.447201

# %%
df.shape
# Out:
# (41363, 12)

# %%
df.head()
# Out:
#        price price_category       type  beds  baths   furnishing  \
# 0  1,450,000         Medium  Apartment     1      2    Furnished
# 1  6,600,000           High  Townhouse     5      5  Unfurnished
# 2  4,825,000           High  Apartment     2      3  Unfurnished
# 3    980,000        Average  Apartment     3      3  Unfurnished
# 4  2,499,999         Medium  Townhouse     3      4    Furnished
#
#   completion_status   post_date       area_name       city   Latitude  \
# 0             Ready  2024-04-15    Business Bay      Dubai  25.189427
# 1             Ready  2024-04-15     DAMAC Hills      Dubai  25.028148
# 2             Ready  2024-04-18  Downtown Dubai      Dubai  25.186684
# 3             Ready  2024-01-03         Al Reef  Abu Dhabi  24.466437
# 4          Off-Plan  2024-02-28      The Valley      Dubai  25.019221
#
#    Longitude
# 0  55.264819
# 1  55.264246
# 2  55.274705
# 3  54.656891
# 4  55.447201

# %%
df = df[['type','beds','baths','furnishing','price_category','post_date','city','area_name','Latitude','Longitude',
        'completion_status','price']]

# %%
df.head()
# Out:
#         type  beds  baths   furnishing price_category   post_date       city  \
# 0  Apartment     1      2    Furnished         Medium  2024-04-15      Dubai
# 1  Townhouse     5      5  Unfurnished           High  2024-04-15      Dubai
# 2  Apartment     2      3  Unfurnished           High  2024-04-18      Dubai
# 3  Apartment     3      3  Unfurnished        Average  2024-01-03  Abu Dhabi
# 4  Townhouse     3      4    Furnished         Medium  2024-02-28      Dubai
#
#         area_name   Latitude  Longitude completion_status      price
# 0    Business Bay  25.189427  55.264819             Ready  1,450,000
# 1     DAMAC Hills  25.028148  55.264246             Ready  6,600,000
# 2  Downtown Dubai  25.186684  55.274705             Ready  4,825,000
# 3         Al Reef  24.466437  54.656891             Ready    980,000
# 4      The Valley  25.019221  55.447201          Off-Plan  2,499,999

# %%
engine = create_engine("mysql+pymysql://root:admin1234@localhost/tableau_work")
df.to_sql("real_estate", engine,if_exists="replace",index=False)
# Out:
# 41363

# %%
# %%sql
# SELECT * FROM real_estate LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost/tableau_work
# 5 rows affected.
# [('Apartment', 1, 2, 'Furnished', 'Medium', '2024-04-15', 'Dubai', 'Business Bay', 25.18942655, 55.26481901527489, 'Ready', '1,450,000'),
#  ('Townhouse', 5, 5, 'Unfurnished', 'High', '2024-04-15', 'Dubai', 'DAMAC Hills', 25.0281481, 55.264246, 'Ready', '6,600,000'),
#  ('Apartment', 2, 3, 'Unfurnished', 'High', '2024-04-18', 'Dubai', 'Downtown Dubai', 25.18668425, 55.27470526460112, 'Ready', '4,825,000'),
#  ('Apartment', 3, 3, 'Unfurnished', 'Average', '2024-01-03', 'Abu Dhabi', 'Al Reef', 24.4664366, 54.65689142777212, 'Ready', '980,000'),
#  ('Townhouse', 3, 4, 'Furnished', 'Medium', '2024-02-28', 'Dubai', 'The Valley', 25.019221, 55.447201, 'Off-Plan', '2,499,999')]

# %%
df.to_csv('final_dataset.csv')
